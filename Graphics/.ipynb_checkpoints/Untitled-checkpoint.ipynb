# %%
import numpy as np
import matplotlib.pyplot as plt
import gym
# %matplotlib inline

# %%
env = gym.make('Seaquest-v4')
obs = env.reset()
# Out:
# [2017-09-24 14:54:24,493] Making new env: Seaquest-v4

# %%
plt.imshow(obs)

# %%
obs.shape
# Out:
# (210, 160, 3)

# %%
image = plt.imread('actions/UP.bmp')
image2 = plt.imread('actions/UPFIRE.bmp')

# %%
plt.imshow(image)
plt.imshow(image2)

# %%
together = np.concatenate((obs,image2),axis=1)
plt.imshow(together)
